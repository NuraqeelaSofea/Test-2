# %%
import numpy as np
import scipy as sc

# %%
A = np.array([[2,4,6],[5,3,2],[7,8,9]])
print(A)
# Out:
# [[2 4 6]
#  [5 3 2]
#  [7 8 9]]

# %%
B = np.array([[18],[13],[30]])
print(B)
# Out:
# [[18]
#  [13]
#  [30]]

# %%
X = sc.linalg.solve(A,B)
print(X)
# Out:
# [[ 4.5]
#  [-7.5]
#  [ 6.5]]

# %%
def dydx(x,y):
  return((x-y)/2)

# %%
def rungeKutta(x0, y0, x, h):
  n = int((x-x0)/h)
  y = y0
  for i in range(1, n+1):
    k1 = h*dydx(x0,y)
    k2 = h*dydx(x0 + 0.5*h, y+0.5*k1)
    k3 = h*dydx(x0 + 0.5*h, y+0.5*k2)
    k4 = h*dydx(x0 + h, y+k3)

    y = y + (1.0/6.0)*(k1 + 2*k2 + 2*k3 + k4)
    x0 = x0 + h
  return y

# %%
x0 = 0
y = 0
x = 1
h = 2
print('The value of y at x is: ', rungeKutta(x0,y,x,h))
# Out:
# The value of y at x is:  0

# %%
plt.plot(x,y)
plt.title('x versus y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1a6819d12f15> in <cell line: 1>()
# ----> 1 plt.plot(x,y)
#       2 plt.title('x versus y')
#       3 plt.xlabel('x')
#       4 plt.ylabel('y')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import requests
api_url = https://api.open-meteo.com/v1/forecast?latitude=2.5&longitude=112.5&hourly=temperature_2m&timezone=Asia%2FSingapore&forecast_days=1

response = requests.get(api_url)
Singapore_forecast = response.json()

days = int(input('Enter number of days for forecast (between 1 to 16 only): '))

for Singapore_forecast:
  print(f"{"time":"iso8601","temperature_2m":"°C"}")
# Out:
#   File "<ipython-input-23-5cca21dd8915>", line 2
#     api_url = https://api.open-meteo.com/v1/forecast?latitude=2.5&longitude=112.5&hourly=temperature_2m&timezone=Asia%2FSingapore&forecast_days=1
#                                                                                                                       ^
# SyntaxError: invalid decimal literal
